# %%
words = [ { 'word': 'inhabit', 'vt.': '居住于，栖居在' },
  { 'word': 'pressure', 'n.': '压力；挤压；液压，气压', 'vt.': '对…施压，逼迫' },
  { 'word': 'peer', 'n.': '同龄人，同辈；(英国的) 贵族', 'vi.': '端详，费力地看' },
  { 'word': 'paradise', 'n.': '天堂，乐土；伊甸园' },
  { 'word': 'involve', 'vt.': '需要，包含；牵涉，涉及；使参与' },
  { 'word': 'mount',
    'vt.': '安排，组织开展；登上；安置',
    'vi.': '逐步增加',
    'vt. vi.': '骑上，乘上',
    'n.': '山峰；坐骑；托架' },
  { 'word': 'notify', 'vt.': '(正式) 通知，告知' },
  { 'word': 'flatter', 'vt.': '奉承，讨好；使…显得更好' },
  { 'word': 'liquid', 'n.': '液体，液态物', 'adj.': '液体的；流动性好的 (资产)' },
  { 'word': 'extent', 'n.': '程度，地步；范围，面积' },
  { 'word': 'lamb', 'n.': '羔羊，小羊；羊羔肉', 'vi.': '(羊) 产羊羔' },
  { 'word': 'harvest',
    'n.': '收获，收割；收成，收获量',
    'vi. vt.': '收获，收割',
    'vt.': '采集，搜集' },
  { 'word': 'chase',
    'vt. vi.': '追逐，追捕；追求，求爱',
    'vt.': '努力获得，争取得到；催促',
    'vi.': '急奔，急赶，匆忙地走',
    'n.': '追赶，追捕；努力获得' },
  { 'word': 'glimpse',
    'n.': '一瞥；短暂的感受，初步的认识',
    'vt.': '瞥见；开始理解，开始领悟' },
  { 'word': 'frown', 'vi. vt.': '皱眉', 'n.': '皱眉' },
  { 'word': 'fairy', 'n.': '小仙子，小精灵' },
  { 'word': 'energetic', 'adj.': '(人) 充满活力的；(活动) 剧烈的' },
  { 'word': 'dust',
    'n.': '尘埃；沙土，尘土；粉末',
    'vi. vt.': '擦去…的灰尘',
    'vt.': '把 (粉末) 撒于' },
  { 'word': 'derive', 'vi.': '起源于，来自', 'vt.': '从…中获得' },
  { 'word': 'display',
    'vt.': '陈列，展示；显示，表现',
    'n.': '陈列；表演；显示，表现；显示器',
    'vi.': '(为求偶而) 炫耀' },
  { 'word': 'deafen', 'vt.': '使变聋，使听不见' },
  { 'word': 'counterpart', 'n.': '职务相当的人，作用相当的事物' },
  { 'word': 'consent', 'n.': '许可，准许，同意', 'vi.': '许可，准许，同意' },
  { 'word': 'remedy', 'n.': '解决方法；药品，疗法', 'vt.': '纠正，补救' },
  { 'word': 'straw', 'n.': '麦秆，稻草；吸管' },
  { 'word': 'compel', 'vt.': '强迫，逼迫' },
  { 'word': 'prospect', 'n.': '可能性；展望；前景，前途', 'vi.': '勘探，探矿' },
  { 'word': 'burial', 'n.': '葬礼，埋葬' },
  { 'word': 'avoid', 'vt.': '避免；回避；避免撞上' },
  { 'word': 'bomb',
    'n.': '炸弹；核武器；彻底的失败',
    'vt.': '轰炸，对…投炸弹',
    'vt. vi.': '(考试) 考砸',
    'vi.': '(戏剧、电影等) 演砸，不卖座' },
  { 'word': 'amuse', 'vt.': '逗笑，逗乐；给…提供娱乐' },
  { 'word': 'accompany', 'vt.': '陪伴，陪同；伴随；为…伴奏' },
  { 'word': 'worm', 'n.': '蠕虫；寄生虫；蠕虫病毒；懦夫', 'vt.': '蠕动，曲折行进；给…驱肠虫' },
  { 'word': 'staff', 'n.': '全体职员；(学校) 行政人员', 'vt.': '担当…职员，任职于' },
  { 'word': 'waterfall', 'n.': '瀑布' },
  { 'word': 'tremendous', 'adj.': '巨大的，大量的；极好的' },
  { 'word': 'variety', 'n.': '各种各样；多样化；种类，品种' },
  { 'word': 'tick',
    'vi.': '(钟表) 发出嘀嗒声',
    'vt.': '打钩，打对号',
    'n.': '嘀嗒声；对号；壁虱；一会儿' },
  { 'word': 'surface',
    'n.': '表面；水面，地面；台面；外表',
    'vi.': '浮到水面；出现，显露；起床' },
  { 'word': 'spacious', 'adj.': '广阔的，宽敞的' },
  { 'word': 'shed', 'n.': '棚屋；厂房；牲口棚', 'vt.': '去除；使落下；蜕；流 (泪、血)' },
  { 'word': 'slavery', 'n.': '奴隶身份；奴隶制，蓄奴制度' },
  { 'word': 'retire', 'vi. vt.': '(使) 退休', 'vi.': '退出，离开；退出比赛，退役' },
  { 'word': 'scream',
    'vi. vt.': '尖叫；高声喊',
    'vi.': '发出大而尖的声音',
    'n.': '尖叫，呼啸声；可笑的人 (或物)' },
  { 'word': 'rare', 'adj.': '少见的；珍稀的；(肉类) 半熟的' },
  { 'word': 'preserve',
    'vt.': '维护，保护；保持；保存 (食物)',
    'n.': '专门领域；蜜饯，果酱；保护区' },
  { 'word': 'plate', 'n.': '盘；一盘；金属牌；车牌；板块', 'vt.': '电镀' },
  { 'word': 'peculiar', 'adj.': '古怪的；特有的；有点不舒服的' },
  { 'word': 'pang', 'n.': '突然的痛苦，一阵剧痛' },
  { 'word': 'oral', 'adj.': '口头的；口腔的，口的', 'n.': '口试' },
  { 'word': 'inform', 'vt.': '通知，告知；了解；影响' },
  { 'word': 'discourage', 'vt.': '打消…的念头，阻止；使灰心' },
  { 'word': 'invite', 'vt.': '邀请；招致', 'n.': '邀请，请柬' },
  { 'word': 'ladder', 'n.': '梯子；(晋升) 阶梯；(裤袜) 抽丝' },
  { 'word': 'hymn', 'n.': '赞美诗，圣歌；歌颂，赞美' },
  { 'word': 'nostril', 'n.': '鼻孔' },
  { 'word': 'motive', 'n.': '(行动的) 动机，缘由', 'adj.': '引起运动的，提供动力的' },
  { 'word': 'method', 'n.': '方法，办法；条理' },
  { 'word': 'manage',
    'vt. vi.': '经营，管理；成功做到',
    'vi.': '勉强维持生活',
    'vt.': '合理使用 (资源)' },
  { 'word': 'limb', 'n.': '肢，臂，腿；大树枝' },
  { 'word': 'harness',
    'vt.': '控制，利用；给 (马等) 上挽具',
    'n.': '马具，挽具；保护带，背带' },
  { 'word': 'strain',
    'n.': '压力；劳损，拉伤；品种',
    'vt.': '拉伤，扭伤，劳损；过度使用',
    'vt. vi.': '尽力，使劲',
    'vi.': '用力推 (或拉)，拉紧' },
  { 'word': 'gleam',
    'vi.': '闪烁，闪耀；(眼睛) 流露出',
    'n.': '微光，反光；(情感的) 表露' },
  { 'word': 'frost', 'n.': '霜冻，严寒天气；霜', 'vt. vi.': '(使) 结霜' },
  { 'word': 'faint',
    'adj.': '(光、声等) 微弱的；渺茫的',
    'vi.': '晕倒，昏厥',
    'n.': '昏厥' },
  { 'word': 'dawn', 'n.': '黎明，拂晓；开端，起始阶段', 'vi.': '破晓，天亮；开始；变得明朗' },
  { 'word': 'flash',
    'vi. vt.': '(使) 闪光；用光发出信号；闪现',
    'vt.': '(快速地) 出示；快速发送 (信息)',
    'vi.': '飞速运动；猛然想起；突然显露',
    'n.': '闪光；闪光灯；闪现；情感突发' },
  { 'word': 'conscience', 'n.': '良心，良知；内疚' },
  { 'word': 'extraordinary', 'adj.': '非凡的，出色的；非常奇特的' },
  { 'word': 'exchange',
    'n.': '交换，交流；交谈；兑换；互访',
    'vt.': '交换，交流；兑换，交易' },
  { 'word': 'dusk', 'n.': '黄昏，傍晚' },
  { 'word': 'depress', 'vt.': '使抑郁；降低 (价格等)；按下' },
  { 'word': 'cottage', 'n.': '乡间小屋，村舍' },
  { 'word': 'comparison', 'n.': '比较，对比' },
  { 'word': 'accidental', 'adj.': '意外的，偶然 (发生) 的' },
  { 'word': 'bureau', 'n.': '局，司，处，署；办事处；衣橱' },
  { 'word': 'charm',
    'n.': '魅力，吸引力；小挂件；咒语',
    'vt. vi.': '吸引，迷住',
    'vt.': '用魔法控制' },
  { 'word': 'blossom',
    'n.': '(树或灌木的) 花，花簇',
    'vi.': '开花；变得健康 (快乐等)，兴旺' },
  { 'word': 'warrior', 'n.': '(尤指旧时的) 勇士，武士' },
  { 'word': 'authority', 'n.': '权力；当局；授权；权威 (人士)' },
  { 'word': 'thunder',
    'n.': '雷，雷声；轰隆声',
    'vi.': '打雷；轰隆隆地响；轰隆隆地动',
    'vi. vt.': '怒喝，大声斥责' },
  { 'word': 'slant',
    'vi. vt.': '使倾斜，歪斜',
    'vt.': '有倾向性地陈述，报道',
    'n.': '倾斜，斜面；(倾向性的) 观点' },
  { 'word': 'ambition', 'n.': '理想，追求；野心，抱负' },
  { 'word': 'woe', 'n.': '麻烦，问题；痛苦，悲伤' },
  { 'word': 'squirrel', 'n.': '松鼠', 'vt.': '贮藏' },
  { 'word': 'vapor', 'n.': '蒸气，水汽' },
  { 'word': 'tremble', 'vi.': '颤抖，战栗；轻晃，震颤；恐惧', 'n.': '颤抖，战栗' },
  { 'word': 'tap',
    'n.': '水龙头；轻敲，轻拍；电话窃听',
    'vt. vi.': '轻敲，轻拍；轻叩；利用，发掘',
    'vt.': '(在电话上) 安装窃听器；委任' },
  { 'word': 'supreme', 'adj.': '至高无上的；(程度上) 最大的' },
  { 'word': 'rapid', 'adj.': '快速的，迅速的' },
  { 'word': 'sow', 'vt. vi.': '播种，种；灌输，散布，煽动', 'n.': '母猪' },
  { 'word': 'proposal', 'n.': '提议，提案；求婚' },
  { 'word': 'planet', 'n.': '行星；地球' },
  { 'word': 'shave',
    'vi. vt.': '刮胡子，剃须',
    'vt.': '(少量地) 削减，调低，降低',
    'n.': '修面，刮脸，剃须' },
  { 'word': 'scratch',
    'vt. vi.': '挠，搔；抓破，抓伤；取消',
    'vt.': '(意外地) 擦破；刮出痕迹',
    'vi.': '刮出刺耳声',
    'n.': '划痕，划伤；刮擦的声音；挠痒' },
  { 'word': 'rust', 'n.': '锈，铁锈', 'vt. vi.': '(使) 生锈' },
  { 'word': 'retain', 'vt.': '保持，保留；储存；预聘 (律师)' },
  { 'word': 'remarkable', 'adj.': '非凡的，不同寻常的' },
  { 'word': 'preparation', 'n.': '准备；准备工作；制剂' },
  { 'word': 'peck',
    'vi. vt.': '啄',
    'vt.': '匆匆地轻吻',
    'n.': '匆匆的吻，轻吻；啄' },
  { 'word': 'palm', 'n.': '手掌，手心；棕榈树', 'vt.': '把…藏在手中 (尤指玩戏法)' },
  { 'word': 'oppose', 'vt.': '反对，阻挠' },
  { 'word': 'mammal', 'n.': '哺乳动物' },
  { 'word': 'normal', 'adj.': '正常的，平常的；身心健康的', 'n.': '通常标准，常态' },
  { 'word': 'motion',
    'n.': '运动，移动；动作；提议',
    'vi. vt.': '(以头或手) 做动作，示意' },
  { 'word': 'lightning', 'n.': '闪电', 'adj.': '闪电似的，极快的' },
  { 'word': 'lack', 'n.': '缺乏，不足', 'vt.': '缺少，欠缺' },
  { 'word': 'humble', 'adj.': '谦逊的；卑微的；不起眼的', 'vt.': '使感到卑微；低声下气' },
  { 'word': 'investigate', 'vi. vt.': '调查，研究' },
  { 'word': 'burden', 'n.': '负担，重负；重担，负荷', 'vt.': '使担负，使烦恼；使负重' },
  { 'word': 'influence',
    'n.': '影响 (力)；有影响的人 (或事物)',
    'vt.': '影响，对…起作用' },
  { 'word': 'hardware', 'n.': '(电脑) 硬件；五金制品；重武器' },
  { 'word': 'glance', 'vi.': '一瞥，扫视；浏览，粗略地看', 'n.': '一瞥，扫视' },
  { 'word': 'flame',
    'n.': '火焰；强烈的感情；橘红色',
    'vi.': '燃烧',
    'vi. vt.': '(因强烈情绪而) 脸红' },
  { 'word': 'extreme', 'adj.': '极度的；严重的；偏激的', 'n.': '极端，极度' },
  { 'word': 'endure', 'vt.': '忍耐，忍受', 'vi.': '持续，延续，持久' },
  { 'word': 'exception', 'n.': '例外；规则的例外，例外的事物' },
  { 'word': 'conquer', 'vt.': '占领，征服；克服' },
  { 'word': 'charitable', 'adj.': '慈善的；仁慈的，宽容的' },
  { 'word': 'witty', 'adj.': '机智幽默的，风趣诙谐的' },
  { 'word': 'disclose', 'vt.': '透露，披露；使显露' },
  { 'word': 'deposit',
    'n.': '订金；押金；存款；沉积物',
    'vt.': '存入银行；放下，放置；使沉积' },
  { 'word': 'dumb', 'adj.': '傻的；哑的；哑口无言的', 'vt.': '降低…的理解难度' },
  { 'word': 'dash',
    'n.': '飞奔，猛冲；少量；破折号',
    'vi.': '飞奔，猛冲',
    'vt. vi.': '猛摔，猛撞' },
  { 'word': 'costume', 'n.': '演出服装；服装，装束；游泳衣' },
  { 'word': 'companion', 'n.': '同伴；成双的物品之一；陪护' },
  { 'word': 'skill', 'n.': '技能，技术' },
  { 'word': 'blind',
    'adj.': '失明的；视而不见的；盲目的',
    'n.': '窗帘，卷帘',
    'vt.': '使变瞎；使眼花；使失去判断力' },
  { 'word': 'treaty', 'n.': '条约，协定' },
  { 'word': 'author', 'n.': '作者，作家；(计划等的) 筹划者', 'vt.': '创作，写作，撰写' },
  { 'word': 'tangle',
    'vt. vi.': '(使) 缠结在一起，(使) 乱成一团',
    'n.': '缠结的一团；混乱，纷乱' },
  { 'word': 'alarm', 'n.': '警报器；警报；闹钟；惊恐', 'vt.': '使惊恐，使忧虑；给…装警报器' },
  { 'word': 'stout', 'adj.': '(人) 肥壮的；结实的；坚决的', 'n.': '(烈性) 黑啤酒' },
  { 'word': 'accept', 'vi. vt.': '接受，同意', 'vt.': '认可；承担；容忍；接纳' },
  { 'word': 'warfare', 'n.': '战争；(不同群体之间的) 冲突' },
  { 'word': 'vanish', 'vi.': '突然消失；消亡，灭绝' },
  { 'word': 'thumb',
    'n.': '拇指；(手套的) 拇指部分',
    'vi.': '快速翻阅',
    'vi. vt.': '翘起拇指请求搭乘；用拇指摸' },
  { 'word': 'superintendent', 'n.': '负责人；警长；(大楼的) 看管人' },
  { 'word': 'sour',
    'adj.': '酸的；馊的；(人) 阴郁的',
    'vi. vt.': '(关系、态度) 变坏；变味，变馊' },
  { 'word': 'square',
    'n.': '正方形；广场；平方',
    'adj.': '正方形的；方的；平方；两清的',
    'vt.': '使成正方形；使成平方',
    'adv.': '正对着地，径直地' },
  { 'word': 'sharp',
    'adj.': '敏锐的；尖刻的；剧烈的',
    'adv.': '…点整',
    'n.': '升半音；锐利的东西' },
  { 'word': 'scrape',
    'vt.': '刮掉',
    'vt. vi.': '(使) 摩擦；艰难取得',
    'n.': '刮，刮擦声；擦伤，擦痕' },
  { 'word': 'ruin', 'vt.': '毁坏，毁掉；使破产', 'n.': '毁坏，毁灭；破产；废墟；祸根' },
  { 'word': 'resume',
    'vt. vi.': '(中断后) 继续',
    'vt.': '恢复 (职位)，回到 (座位)',
    'n.': '摘要，概述' },
  { 'word': 'invent', 'vt.': '发明，创造；捏造，虚构' },
  { 'word': 'religious', 'adj.': '宗教的；虔诚的，笃信宗教的' },
  { 'word': 'range',
    'n.': '一系列；范围；射程；山脉',
    'vi.': '(在一定的范围内) 变化；包括',
    'vt.': '(按一定顺序) 排列',
    'vi. vt.': '徘徊，漫步' },
  { 'word': 'opportunity', 'n.': '机会，时机' },
  { 'word': 'proportion', 'n.': '部分，份额；比例；匀称；规模' },
  { 'word': 'frighten', 'vt. vi.': '使害怕，吓唬' },
  { 'word': 'preface',
    'n.': '(书的) 序言，前言，绪论',
    'vt.': '以…为开端，以…作为开场白' },
  { 'word': 'peasant', 'n.': '农民，佃农' },
  { 'word': 'pity', 'n.': '同情，怜悯；遗憾，可惜', 'vt.': '同情，怜悯' },
  { 'word': 'palace', 'n.': '宫殿，总统府；王室；豪宅' },
  { 'word': 'inferior', 'adj.': '较差的，较次的；级别低的', 'n.': '下级，下属' },
  { 'word': 'deny', 'vt.': '否认；拒绝接受；拒绝给予' },
  { 'word': 'mortal', 'adj.': '终有一死的；致命的；极度的', 'n.': '人，凡人，普通人' },
  { 'word': 'merit', 'n.': '优秀品质，价值；优点，长处', 'vt.': '值得，应受到' },
  { 'word': 'male', 'adj.': '男性的，雄的，公的', 'n.': '男性，雄性动植物' },
  { 'word': 'lighten',
    'vt.': '减轻，减少；减轻重量',
    'vt. vi.': '(使) 变明亮，变成淡色；缓和' },
  { 'word': 'huge', 'adj.': '巨大的，极多的，程度深的' },
  { 'word': 'fade', 'vi. vt.': '(使) 褪色，(使) 变暗淡', 'vi.': '逐渐消失' },
  { 'word': 'hardship', 'n.': '艰苦，贫困' },
  { 'word': 'ghost', 'n.': '鬼，鬼魂；一丝，一点；回忆', 'vt. vi.': '代人写作' },
  { 'word': 'fist', 'n.': '拳头' },
  { 'word': 'endeavor', 'vi.': '努力，尽力', 'n.': '努力，尝试' },
  { 'word': 'excellence', 'n.': '优秀，卓越，杰出' },
  { 'word': 'dull',
    'adj.': '迟钝的；钝的；沉闷的',
    'vt. vi.': '使麻木，使迟钝；(使) 变得暗淡' },
  { 'word': 'discharge',
    'vt.': '准许离开，解雇；履行；开火',
    'vi. vt.': '排出，放出；放 (电)',
    'n.': '排出 (物)；获准离开；履行' },
  { 'word': 'witness',
    'n.': '目击者；(出庭的) 证人；见证人',
    'vt.': '目击，目睹；见证；连署' },
  { 'word': 'darken', 'vi. vt.': '(使) 变暗；(使) 忧郁' },
  { 'word': 'correspond', 'vi.': '相符，一致；类似，相当；通信' },
  { 'word': 'sketch',
    'n.': '素描，草图；简报，概述；小品',
    'vt. vi.': '画素描，画速写',
    'vt.': '概述，简述' },
  { 'word': 'communicate', 'vi. vt.': '交流，沟通；表达，传达' },
  { 'word': 'connect',
    'vt. vi.': '(使) 连接，(使) 联结',
    'vt.': '把…联系起来；为…接通电话',
    'vi.': '衔接；与某人建立关系；击中' },
  { 'word': 'bundle', 'n.': '捆，包；一批 (同类事物)；巨款', 'vt.': '匆匆送走；捆绑销售' },
  { 'word': 'characteristic', 'n.': '特色，特点', 'adj.': '典型的，独特的，特有的' },
  { 'word': 'bless', 'vt.': '求上帝降福，祝福；称颂上帝', 'int.': '哎呀，太好啦，太谢谢了' },
  { 'word': 'audience', 'n.': '观众，听众，读者；正式会见' },
  { 'word': 'scout',
    'n.': '童子军；侦察员，侦察机；星探',
    'vt. vi.': '侦察，搜寻 (某处)；物色' },
  { 'word': 'accentuate', 'vt.': '使突出，强调' },
  { 'word': 'aim',
    'n.': '目的，目标；瞄准',
    'vi. vt.': '力求达到；瞄准',
    'vt.': '旨在；针对' },
  { 'word': 'rage',
    'n.': '暴怒，狂怒；流行一时的事物',
    'vi. vt.': '发怒，怒斥',
    'vi.': '猛烈地进行；迅速蔓延' },
  { 'word': 'wage', 'n.': '工资，工钱', 'vt.': '发动，进行 (运动或战争)' },
  { 'word': 'vaccinate', 'vt.': '给…接种疫苗' },
  { 'word': 'trap', 'n.': '陷阱，圈套；困境，牢笼；嘴', 'vt.': '留存，储存(气、水等)' },
  { 'word': 'thrust', 'vt. vi.': '猛推，挤；刺，戳', 'n.': '猛推，刺，戳；驱动力；要点' },
  { 'word': 'summon', 'vt.': '召唤；传唤出庭；召开；请求' },
  { 'word': 'tame',
    'adj.': '驯化的；乏味的；(人) 温顺的',
    'vt.': '驯服，使驯化；控制，驾驭' },
  { 'word': 'storage', 'n.': '储藏，贮存；(计算机) 存储' },
  { 'word': 'spy',
    'n.': '间谍，密探',
    'vi.': '从事间谍活动，搜集情报',
    'vt.': '突然看见，发现' },
  { 'word': 'sound',
    'n.': '声音，声响',
    'vt. vi.': '听起来；鸣警报',
    'adj.': '透彻的，全面的；酣畅的' },
  { 'word': 'shame', 'n.': '羞耻，惭愧；让人遗憾的事', 'vt.': '使羞愧 (或惭愧)；使丢脸' },
  { 'word': 'rug', 'n.': '小地毯；男用假发' },
  { 'word': 'restless', 'adj.': '坐立不安的；没有真正休息的' },
  { 'word': 'relieve', 'vt.': '减轻，缓和；给…换班；解手' },
  { 'word': 'moral', 'adj.': '道德的；出于道义的；有道德的', 'n.': '品行，道德；寓意' },
  { 'word': 'property', 'n.': '财产，所有物；房地产；特性' },
  { 'word': 'pitch',
    'n.': '球场；音高；沥青；宣传论点',
    'vt.': '用力扔；搭 (帐篷)；定音高',
    'vi. vt.': '投球；推销',
    'vi.': '颠簸，上下飘荡' },
  { 'word': 'pearl', 'n.': '珍珠；珠状物' },
  { 'word': 'precious', 'adj.': '珍贵的；珍稀的；被珍惜的', 'adv.': '(强调太少) 非常' },
  { 'word': 'painful', 'adj.': '令人疼痛的；令人痛苦的' },
  { 'word': 'fable', 'n.': '寓言；谎言，无稽之谈' },
  { 'word': 'nod', 'vi. vt.': '点头，点头致意', 'vi.': '打盹，打瞌睡', 'n.': '点头' },
  { 'word': 'operate',
    'vt.': '操作，使运行',
    'vi.': '运转，工作；动手术；经营',
    'vi. vt.': '(被) 使用，(使) 运转' },
  { 'word': 'majority', 'n.': '大部分，大多数；多数票' },
  { 'word': 'frequent', 'adj.': '经常性的，频繁的', 'vt.': '常到，常去，常出入于' },
  { 'word': 'lid', 'n.': '盖，盖子' },
  { 'word': 'mercy', 'n.': '仁慈，宽恕；幸运，恩惠' },
  { 'word': 'labor',
    'n.': '劳动；劳动力；分娩；英国工党',
    'vi.': '努力做 (困难的事)；干苦力活' },
  { 'word': 'introduce', 'vt.': '介绍；使初次了解；推行；引入' },
  { 'word': 'infamous', 'adj.': '臭名远扬的，声名狼藉的' },
  { 'word': 'howl',
    'vi.': '嗥叫，长嚎；大声叫喊；呼啸',
    'vi. vt.': '怒吼，怒声要求',
    'n.': '嗥叫，长嚎；喊叫声' },
  { 'word': 'harbor', 'n.': '港口，港湾', 'vt.': '窝藏，庇护；心怀；包含，藏有' },
  { 'word': 'evident', 'adj.': '明显的，显然的' },
  { 'word': 'genius', 'n.': '天才人物；天才，天赋；本领' },
  { 'word': 'firm',
    'n.': '公司，商行，事务所',
    'adj.': '坚硬的；牢固的；坚定的',
    'vt.': '使强壮，使坚固',
    'vi.': '回升，稳步上涨' },
  { 'word': 'attraction', 'n.': '吸引力；有吸引力的事物' },
  { 'word': 'encourage', 'vt.': '鼓励；劝告，怂恿；促进，刺激' },
  { 'word': 'demand', 'n.': '要求；需求', 'vt.': '要求；需要' },
  { 'word': 'correction', 'n.': '批改；改正，修正', 'int.': '改正一下' },
  { 'word': 'drown', 'vi. vt.': '(使…) 溺死，淹死', 'vt.': '(指声音) 盖过' },
  { 'word': 'disappoint', 'vt. vi.': '(使) 失望', 'vt.': '使…破灭' },
  { 'word': 'blaze', 'n.': '火灾，烈火；光辉，闪耀；迸发', 'vi.': '熊熊燃烧；闪耀；怒视' },
  { 'word': 'commit', 'vt.': '犯 (错或罪)；承诺；花费', 'vi.': '忠于，全心全意投入' },
  { 'word': 'stoop', 'vi.': '俯身，弯腰；(站立时) 弓背', 'n.': '驼背；门廊' },
  { 'word': 'wither', 'vt. vi.': '枯萎，凋谢；萎缩' },
  { 'word': 'damp',
    'adj.': '潮湿的，湿气重的',
    'n.': '潮湿，湿气',
    'vt.': '使潮湿；抑制(感情等)' },
  { 'word': 'congress', 'n.': '代表大会；国会' },
  { 'word': 'challenge', 'n.': '挑战，艰巨任务；质疑', 'vt.': '质疑；向…发出挑战' },
  { 'word': 'ahead', 'adv.': '向前面；提前；领先' },
  { 'word': 'academic', 'adj.': '学术的；纯理论的；学习良好的', 'n.': '大学教师，学者' },
  { 'word': 'voyage', 'n.': '航行，航海，航天', 'vi.': '航行，航海' },
  { 'word': 'utter', 'adj.': '完全的，彻底的', 'vt.': '发出 (声音)，说' },
  { 'word': 'throughout',
    'prep.': '遍及；自始至终，从头到尾',
    'adv.': '自始至终，从头到尾' },
  { 'word': 'talkative', 'adj.': '话多的，健谈的' },
  { 'word': 'transport',
    'n.': '交通运输系统；交通工具；运输',
    'vt.': '运输；使…仿佛置身于' },
  { 'word': 'sum', 'n.': '金额；总和，总数；全部；算数', 'vi. vt.': '总结，概括' },
  { 'word': 'majesty', 'n.': '雄伟壮观，庄严；(尊称) 陛下' },
  { 'word': 'sprinkle', 'vt.': '洒，撒；使零星分布，点缀', 'n.': '少量，一点；小雨' },
  { 'word': 'shallow', 'adj.': '浅的；肤浅的；(呼吸) 微弱的' },
  { 'word': 'soul', 'n.': '灵魂；精神，精髓；某种人' },
  { 'word': 'responsibility', 'n.': '责任' },
  { 'word': 'scorn', 'n.': '轻蔑，鄙视', 'vt.': '轻蔑，鄙视' },
  { 'word': 'rude', 'adj.': '粗鲁的；下流的；猛然的' },
  { 'word': 'rag', 'n.': '抹布，破布；破旧衣服；小报', 'vt.': '嘲笑，捉弄' },
  { 'word': 'release',
    'vt.': '释放；松开；发泄；解雇；发布',
    'n.': '释放；公开，发行；排放；解脱' },
  { 'word': 'proof',
    'n.': '证据；证实；求证；校样',
    'adj.': '能防范的',
    'suff.': '防…的，抗…的',
    'vt.': '校对' },
  { 'word': 'freight', 'n.': '货物，货运；运费', 'vt.': '(用飞机等) 运送，托运' },
  { 'word': 'preach', 'vi. vt.': '讲道，布道；宣传，鼓吹', 'vi.': '说教，唠叨' },
  { 'word': 'pit', 'n.': '深坑；煤矿井；果核；乐池', 'vt.': '使有凹陷' },
  { 'word': 'monument', 'n.': '纪念碑，纪念馆；名胜；典范' },
  { 'word': 'peak',
    'n.': '顶峰，巅峰；山顶；尖头；帽檐',
    'vi.': '到达最高值',
    'adj.': '高峰时期的' },
  { 'word': 'intimate',
    'adj.': '亲密的；隐私的；幽静舒适的',
    'vt.': '透露，(间接) 表示，暗示',
    'n.': '知己，密友，至交' },
  { 'word': 'onion', 'n.': '洋葱，洋葱头' },
  { 'word': 'nickname', 'n.': '绰号，外号', 'vt.': '给…取绰号' },
  { 'word': 'industrious', 'adj.': '勤劳的，勤奋的' },
  { 'word': 'mention', 'vt.': '提及，说起', 'n.': '提及，说起' },
  { 'word': 'liberty', 'n.': '自由；(某种) 合法权利；失礼' },
  { 'word': 'knowledge', 'n.': '知识，学问；知悉，知情' },
  { 'word': 'horrible', 'adj.': '糟透的；可怕的；不友好的' },
  { 'word': 'handy', 'adj.': '有用的，方便的；手边的；手巧的' },
  { 'word': 'generous', 'adj.': '慷慨的；大量的；宽宏大量的' },
  { 'word': 'faculty', 'n.': '院系；全体教员；机能；能力' },
  { 'word': 'financial', 'adj.': '财政的，金融的，财务的' },
  { 'word': 'evidence', 'n.': '证据，证明', 'vt.': '证明，表明' },
  { 'word': 'employ', 'vt.': '雇用，雇佣；使用，运用' },
  { 'word': 'drift',
    'vi.': '漂流，漂；缓缓移动',
    'vt.': '使漂流，使漂浮',
    'n.': '雪堆；水流，气流；主旨；偏航' },
  { 'word': 'ceremony', 'n.': '仪式，典礼；礼数，客套' },
  { 'word': 'curse',
    'n.': '骂人的话；咒语；祸根',
    'vi.': '咒骂',
    'vt.': '(嘴上或心里) 咒骂；诅咒' },
  { 'word': 'disappear', 'vi.': '消失，不见；不复存在；失踪' },
  { 'word': 'delight', 'n.': '高兴，愉快；令人高兴的事 (人)', 'vt.': '使高兴，使愉快' },
  { 'word': 'agency', 'n.': '代理机构；(政府的) 专门机构' },
  { 'word': 'bulk', 'n.': '大部分；大体积，大量' },
  { 'word': 'pronounce', 'vt.': '发…的音；正式宣布，宣告' },
  { 'word': 'attitude', 'n.': '态度，看法；我行我素的作风' },
  { 'word': 'confuse', 'vt.': '使困惑；将…混淆；使复杂化' },
  { 'word': 'copper', 'n.': '铜；铜币，铜板；警察' },
  { 'word': 'commerce', 'n.': '商业，贸易' },
  { 'word': 'blank',
    'adj.': '空白的；没表情的；(墙等) 空的',
    'n.': '空白处；(记忆的) 空白；空弹',
    'vi.': '突然忘掉，突然思路模糊' },
  { 'word': 'talent', 'n.': '天资，天赋；有才能的人' },
  { 'word': 'absolute', 'adj.': '绝对的；无疑的；不受约束的', 'n.': '绝对真理' },
  { 'word': 'withdraw',
    'vi. vt.': '(使) 撤回，撤离；(使) 退出',
    'vt.': '收回，撤销；取 (款)；停止供应',
    'vi.': '不与人交往' },
  { 'word': 'vowel', 'n.': '元音，元音字母' },
  { 'word': 'usage', 'n.': '(词语的) 用法；使用 (量)' },
  { 'word': 'transfer',
    'vi. vt.': '转移；移交；转存；换乘；转会',
    'vt.': '转账；转让；传染',
    'n.': '搬迁，转移，调动；转会；换乘' },
  { 'word': 'throne', 'n.': '(君王的) 宝座；王位，王权' },
  { 'word': 'suitcase', 'n.': '手提箱' },
  { 'word': 'spread',
    'vt.': '展开，摊开；伸开；使分散',
    'vi. vt.': '传播，散布；蔓延，扩散；涂',
    'n.': '传播，散布；区域；翼展' },
  { 'word': 'stomach', 'n.': '胃，腹部', 'vt.': '承受，忍受；吃得下' },
  { 'word': 'sore', 'adj.': '疼痛的，酸痛的；恼火的', 'n.': '痛处，伤处，疮' },
  { 'word': 'relative', 'n.': '亲戚，亲属', 'adj.': '相对的；与…相比；关于…的' },
  { 'word': 'race',
    'n.': '赛跑，竞速比赛；竞争；种族',
    'vi. vt.': '参加比赛；(使) 快速移动' },
  { 'word': 'resort', 'n.': '度假胜地；采用的方法', 'vi.': '诉诸，求助' },
  { 'word': 'pioneer', 'n.': '先驱，先锋；开拓者，拓荒者', 'vt.': '开创，倡导' },
  { 'word': 'situation', 'n.': '情况，形势；位置，环境；工作' },
  { 'word': 'shadow',
    'n.': '阴影；阴暗处；少许',
    'vt.': '跟踪，盯梢；跟随…实地学习',
    'adj.': '影子内阁的' },
  { 'word': 'interval', 'n.': '间隔；中场休息' },
  { 'word': 'rub',
    'vt. vi.': '擦，摩，搓；摩擦',
    'vt.': '涂，抹',
    'n.': '擦，搓，揉；问题，困难' },
  { 'word': 'pray',
    'vi. vt.': '祈望，祈求；祈祷，祷告',
    'adv.': '(用于提问或要求) 请问，请' },
  { 'word': 'peacock', 'n.': '雄孔雀' },
  { 'word': 'liberal', 'adj.': '慷慨的；不完全准确的', 'n.': '支持变革的人；自由党成员' },
  { 'word': 'omit', 'vt.': '省略，删节，遗漏；未 (做)' },
  { 'word': 'neutral', 'adj.': '中立的；中性的；素净的', 'n.': '(汽车排档) 空档；中立者' },
  { 'word': 'individual', 'adj.': '单独的；个人的；独特的', 'n.': '个人；有个性的人' },
  { 'word': 'mental', 'adj.': '精神上的；智力的；疯狂的' },
  { 'word': 'magnificent', 'adj.': '宏伟的，令人印象深刻的' },
  { 'word': 'momentary', 'adj.': '瞬息的，片刻的，短暂的' },
  { 'word': 'frank', 'adj.': '坦率的，直率的' },
  { 'word': 'knot',
    'n.': '结；发髻；节疤；痉挛',
    'vt.': '把…打成结(或扎牢)',
    'vi.': '缠结',
    'vi. vt.': '(因害怕等而) 痉挛，使痉挛' },
  { 'word': 'attend',
    'vi. vt.': '出席，参加',
    'vt.': '去 (学校等)；陪同；伴随',
    'vi.': '注意，专心；照顾' },
  { 'word': 'file',
    'n.': '文件夹；文件；档案',
    'vt.': '把…归档；锉光滑',
    'vi. vt.': '提起 (诉讼)，提交 (申请)',
    'vi.': '排成纵队行走' },
  { 'word': 'horn', 'n.': '(动物的) 角；(乐器) 号；喇叭' },
  { 'word': 'halt', 'vi. vt.': '(使) 停止', 'n.': '停止，暂停' },
  { 'word': 'generate', 'vt.': '产生，引起；发电，产生 (能量)' },
  { 'word': 'commendation', 'n.': '奖品，奖励，表扬' },
  { 'word': 'event', 'n.': '事件；公开活动；体育项目' },
  { 'word': 'failure', 'n.': '失败；失败者；未做；故障' },
  { 'word': 'empire', 'n.': '帝国；企业集团' },
  { 'word': 'draw',
    'vt. vi.': '画，描绘；拔出，抽出',
    'vt.': '拖动；拉帘；吸引；得出；支取',
    'vi.': '移动，行进',
    'n.': '抽奖，抽签；平局，和局' },
  { 'word': 'direct',
    'adj.': '直接的；径直的；坦率的',
    'vt.': '对准；指导；指路；指示',
    'vt. vi.': '导演，指挥',
    'adv.': '直接' },
  { 'word': 'abroad', 'adv.': '在国外，去国外；广为流传地' },
  { 'word': 'delicious', 'adj.': '美味的，可口的；令人愉快的' },
  { 'word': 'curious', 'adj.': '好奇的；稀奇古怪的，不寻常的' },
  { 'word': 'affect', 'vt.': '影响；(疾病) 侵袭；打动；假装' },
  { 'word': 'blame', 'vt.': '责怪，把…归咎于', 'n.': '(坏事或错事的) 责任，责备' },
  { 'word': 'cooperate', 'vi.': '合作，协作；协助，配合' },
  { 'word': 'conflict', 'n.': '争执；(军事) 冲突；不一致', 'vi.': '相互矛盾，冲突' },
  { 'word': 'cemetery', 'n.': '墓地，公墓' },
  { 'word': 'bubble', 'n.': '气泡；肥皂泡；经济泡沫', 'vi.': '起泡，冒泡；(情绪等) 涌动' } ]

# %%
import re
from pypinyin import lazy_pinyin

splitRe = re.compile('；|，')
rmRe = re.compile('\(.*?\) *')
result = []

for w in words:
    tras = []
    buf = {'word':w['word'], 'tras': tras}
    result.append(buf)
    for k, v in list(w.items())[1:]:
        tras.append({'type':k, 'tras':splitRe.split(v)})
    mainTra = rmRe.sub('', tras[0]['tras'][0])
    buf['mainTra'] = {'type': tras[0]['type'], 'zh':mainTra, 'py': lazy_pinyin(mainTra)}

# %%
import json

with open('words.json', 'w') as f:
    json.dump(result, f, ensure_ascii=False)
